# %%
#CREATE A TEXT GENERATION MODEL USING GPT OR LSTM TO GENERATE COHERENT PARAGRAPHS ON SPECIFIC TOPICS.
#DELIVERABLE: A NOTEBOOK DEMONSTRATING GENERATED TEXT BASED ON USER PROMPTS.

#Text generation is a technique that involves the creation of human-like text using artificial intelligence 
#  and machine learning algorithms. It enables computers to generate coherent and contextually relevant text 
#  based on patterns and structures learned from existing textual data.

#Text generation is a fascinating application of deep learning in natural language processing (NLP). 
#  It involves training a model on a given text dataset, which can then generate new, coherent sequences 
#  of text based on the patterns it has learned.

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Define the Sample text that will be used to train the model 

input_text ="""In a survey of nearly 75,000 adults, researchers compared the participants' preferred sleep timing, known as chronotype, with their actual sleep behavior. They determined that regardless of one's preferred bedtime, everyone benefits from turning in early. Morning larks and night owls alike tended to have higher rates of mental and behavioral disorders if they stayed up late," the researchers from Stanford Medicine have said."""

# %%
# To train the model, the input text needs to be converted into a numerical format. 
# This is done using Keras’s Tokenizer, which converts the words in the text to sequences of integers. 
# Each unique word is assigned a specific index, and the tokenizer creates a mapping of words to indices.

# Tokenize the text
tokenizer = Tokenizer()

#fit_on_texts(): Creates the word-to-index mapping
tokenizer.fit_on_texts([input_text])

#Stores the number of unique words in the given input text (plus one for padding).
total_words = len(tokenizer.word_index) + 1

# %%
#fit_on_texts used in conjunction with texts_to_sequences produces the one-hot encoding for a text
# Create sequences for text generation
# For example 'Morning Larks and night' will generate the below sequences
#"Morning Larks"
#"Morning Larks and"
#"Morning Larks and night"

input_sequences = []
for line in input_text.split('.'):
   token_list = tokenizer.texts_to_sequences([line])[0]
   for i in range(1, len(token_list)):
       n_gram_sequence = token_list[:i+1]
       input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[2, 11],
#  [2, 11, 12],
#  [2, 11, 12, 1],
#  [2, 11, 12, 1, 13],
#  [2, 11, 12, 1, 13, 14],
#  [2, 11, 12, 1, 13, 14, 15],
#  [2, 11, 12, 1, 13, 14, 15, 16],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22, 23],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22, 23, 24],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25,
#   6],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25,
#   6,
#   26],
#  [7, 27],
#  [7, 27, 28],
#  [7, 27, 28, 29],
#  [7, 27, 28, 29, 1],
#  [7, 27, 28, 29, 1, 30],
#  [7, 27, 28, 29, 1, 30, 5],
#  [7, 27, 28, 29, 1, 30, 5, 31],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34, 2],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34, 2, 35],
#  [36, 37],
#  [36, 37, 9],
#  [36, 37, 9, 38],
#  [36, 37, 9, 38, 39],
#  [36, 37, 9, 38, 39, 40],
#  [36, 37, 9, 38, 39, 40, 41],
#  [36, 37, 9, 38, 39, 40, 41, 42],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7, 49],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7, 49, 50],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53,
#   10],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53,
#   10,
#   54]]

# %%
# The above command split each sentence into sequences of increasing length, creating the n-gram sequences necessary for training.
# The sequences generated in the previous step are of varying lengths. Since the model requires all input sequences 
# to be of the same length, we pad them to a uniform size using pad_sequences(). 
# The padding is done at the beginning of the sequences to ensure that the sequences are aligned properly.
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# %%
# input sequences are now padded with zeros
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  2, 11],
#        [ 0,  0,  0, ...,  2, 11, 12],
#        [ 0,  0,  0, ..., 11, 12,  1],
#        ...,
#        [ 0,  0, 36, ...,  8, 52, 53],
#        [ 0, 36, 37, ..., 52, 53, 10],
#        [36, 37,  9, ..., 53, 10, 54]])

# %%
# Preparing the input and output for the model 
# Each sequence is split into input (X) and output (y). 
# The input consists of all words in the sequence except the last one
# the output is the last word in the sequence. 
# The output (y) is one-hot encoded to allow the model to predict the next word from a vocabulary of all possible words.
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
# Build LSTM model for text generation
# Embedding Layer - Converts the input word indices into dense vectors of fixed size.
# LSTM Layer - Processes the input sequences and learns the temporal relationships between words.
# Dense Layer - Outputs a probability distribution over the vocabulary using a softmax activation function, which predicts the next word in the sequence.

model_textgen_lstm = Sequential()
model_textgen_lstm.add(Embedding(total_words, 64, input_length=max_sequence_len-1))
model_textgen_lstm.add(LSTM(100))
model_textgen_lstm.add(Dense(total_words, activation='softmax'))
# Out:
# C:\Users\Karthikeyan\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile the model using the Adam optimizer and categorical crossentropy as the loss function. 
model_textgen_lstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model for 100 epochs.
model_textgen_lstm.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.0000e+00 - loss: 4.0072
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0430 - loss: 4.0004
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1169 - loss: 3.9928
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.0746 - loss: 3.9865
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0531 - loss: 3.9742
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0743 - loss: 3.9583
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0427 - loss: 3.9366
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0531 - loss: 3.8965
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0427 - loss: 3.8752
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0427 - loss: 3.8751
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0850 - loss: 3.8023
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0430 - loss: 3.7724
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0743 - loss: 3.7444
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1062 - loss: 3.6726
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.0746 - loss: 3.6153
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0749 - loss: 3.5766
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1062 - loss: 3.5028
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1169 - loss: 3.4441
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1169 - loss: 3.4300
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1274 - loss: 3.3557
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0746 - loss: 3.3764
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1169 - loss: 3.3275
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1062 - loss: 3.2649
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1381 - loss: 3.2098
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1065 - loss: 3.1607
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1697 - loss: 3.1117
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1704 - loss: 3.0871
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2339 - loss: 3.0500
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2658 - loss: 2.9995
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2241 - loss: 2.9748
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2873 - loss: 2.8730
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2977 - loss: 2.8334
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3196 - loss: 2.7693
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3720 - loss: 2.7347
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3827 - loss: 2.6612
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3515 - loss: 2.6036
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3612 - loss: 2.5639
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3411 - loss: 2.5376
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4358 - loss: 2.5202
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4147 - loss: 2.4451
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4133 - loss: 2.3160
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3938 - loss: 2.3724
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4563 - loss: 2.2807
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4674 - loss: 2.2157
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5312 - loss: 2.1887
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4573 - loss: 2.1809
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4681 - loss: 2.1080
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5423 - loss: 2.0634
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4993 - loss: 2.0586
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5212 - loss: 2.0292
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5843 - loss: 1.9294
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5743 - loss: 1.9540
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5954 - loss: 1.8857
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5958 - loss: 1.8653
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6593 - loss: 1.8243
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6065 - loss: 1.8309
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7120 - loss: 1.7586
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7339 - loss: 1.7446
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7231 - loss: 1.7153
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7342 - loss: 1.6829
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7453 - loss: 1.6594
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7655 - loss: 1.6152
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7658 - loss: 1.5759
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7769 - loss: 1.5962
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8081 - loss: 1.5479
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8078 - loss: 1.4723
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7977 - loss: 1.4692
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8085 - loss: 1.4457
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8293 - loss: 1.4246
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7981 - loss: 1.3953
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8296 - loss: 1.3618
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8827 - loss: 1.3515
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8619 - loss: 1.3394
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8401 - loss: 1.3023
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8511 - loss: 1.3005
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8511 - loss: 1.2836
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9466 - loss: 1.2481
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9254 - loss: 1.2324
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9150 - loss: 1.2153
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9362 - loss: 1.1947
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9150 - loss: 1.1714
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9362 - loss: 1.1585
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9150 - loss: 1.1316
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9573 - loss: 1.1233
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9469 - loss: 1.1062
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9577 - loss: 1.1007
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9469 - loss: 1.1058
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9577 - loss: 1.0923
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9466 - loss: 1.0348
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9788 - loss: 1.0553
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9681 - loss: 1.0313
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9469 - loss: 1.0281
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9788 - loss: 0.9908
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9788 - loss: 1.0170
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9681 - loss: 0.9848
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9788 - loss: 0.9586
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9788 - loss: 0.9666
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9892 - loss: 0.9211
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9681 - loss: 0.9332
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9892 - loss: 0.8965

# %%
# A trained model can be used to generate new text. 
# The function generate_text() takes a seed text and generates a specified number of new words by predicting
#   the next word repeatedly, updating the seed text with the new predictions.
def generate_text(seed_text, next_words, max_sequence_len):
   for _ in range(next_words):
       token_list = tokenizer.texts_to_sequences([seed_text])[0]
       token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
       predicted = np.argmax(model_textgen_lstm.predict(token_list), axis=-1)
       output_word = ""
       for word, index in tokenizer.word_index.items():
           if index == predicted:
               output_word = word
               break
       seed_text += " " + output_word
   return seed_text

# %%
# Test your LSTM model. Pass a seed text and see how the model generate the text
print(generate_text("Morning larks", 20, max_sequence_len))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Morning larks and night owls alike tended to have higher rates of mental and behavioral disorders if they stayed up late the
